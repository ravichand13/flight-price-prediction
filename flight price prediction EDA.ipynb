# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1=pd.read_excel('Test_set.xlsx')

# %%
df2=pd.read_excel('Data_Train.xlsx')

# %%
df=df1.append(df2)
# Out:
# C:\Users\cheru\AppData\Local\Temp\ipykernel_14200\2456558213.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df1.append(df2)

# %%
df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Price
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Date_of_Journey  13354 non-null  object
#  2   Source           13354 non-null  object
#  3   Destination      13354 non-null  object
#  4   Route            13353 non-null  object
#  5   Dep_Time         13354 non-null  object
#  6   Arrival_Time     13354 non-null  object
#  7   Duration         13354 non-null  object
#  8   Total_Stops      13353 non-null  object
#  9   Additional_Info  13354 non-null  object
#  10  Price            10683 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 1.2+ MB

# %%
df['Date']=df['Date_of_Journey'].str.split("/").str[0]
df['Month']=df['Date_of_Journey'].str.split("/").str[1]
df['Year']=df['Date_of_Journey'].str.split("/").str[2]

# %%
#we can use lambda fxn .apply(lambda x:x.split("/")[0])

# %%
df.head()
# Out:
#              Airline Date_of_Journey    Source Destination            Route  \
# 0        Jet Airways       6/06/2019     Delhi      Cochin  DEL → BOM → COK
# 1             IndiGo      12/05/2019   Kolkata    Banglore  CCU → MAA → BLR
# 2        Jet Airways      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 3  Multiple carriers      21/05/2019     Delhi      Cochin  DEL → BOM → COK
# 4           Air Asia      24/06/2019  Banglore       Delhi        BLR → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops              Additional_Info  \
# 0    17:30  04:25 07 Jun  10h 55m      1 stop                      No info
# 1    06:20         10:20       4h      1 stop                      No info
# 2    19:15  19:00 22 May  23h 45m      1 stop  In-flight meal not included
# 3    08:00         21:00      13h      1 stop                      No info
# 4    23:55  02:45 25 Jun   2h 50m    non-stop                      No info
#
#    Price Date Month  Year
# 0    NaN    6    06  2019
# ...

# %%
df['Date']=df['Date'].astype(int)
df['Month']=df['Month'].astype(int)
df['Year']=df['Year'].astype(int)

# %%
df.drop('Date_of_Journey',axis=1,inplace=True)
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#    Arrival_Time Duration Total_Stops              Additional_Info  Price  \
# 0  04:25 07 Jun  10h 55m      1 stop                      No info    NaN
# 1         10:20       4h      1 stop                      No info    NaN
# 2  19:00 22 May  23h 45m      1 stop  In-flight meal not included    NaN
# 3         21:00      13h      1 stop                      No info    NaN
# 4  02:45 25 Jun   2h 50m    non-stop                      No info    NaN
#
#    Date  Month  Year
# 0     6      6  2019
# 1    12      5  2019
# 2    21      5  2019
# ...

# %%
df['Arrival_Time']=df['Arrival_Time'].str.split(' ').str[0]
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#   Arrival_Time Duration Total_Stops              Additional_Info  Price  Date  \
# 0        04:25  10h 55m      1 stop                      No info    NaN     6
# 1        10:20       4h      1 stop                      No info    NaN    12
# 2        19:00  23h 45m      1 stop  In-flight meal not included    NaN    21
# 3        21:00      13h      1 stop                      No info    NaN    21
# 4        02:45   2h 50m    non-stop                      No info    NaN    24
#
#    Month  Year
# 0      6  2019
# 1      5  2019
# 2      5  2019
# ...

# %%
df['Arrival_hour']=df['Arrival_Time'].str.split(':').str[0].astype(int)
df['Arrival_min']=df['Arrival_Time'].str.split(':').str[1].astype(int)
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55
#
#   Arrival_Time Duration Total_Stops              Additional_Info  Price  Date  \
# 0        04:25  10h 55m      1 stop                      No info    NaN     6
# 1        10:20       4h      1 stop                      No info    NaN    12
# 2        19:00  23h 45m      1 stop  In-flight meal not included    NaN    21
# 3        21:00      13h      1 stop                      No info    NaN    21
# 4        02:45   2h 50m    non-stop                      No info    NaN    24
#
#    Month  Year  Arrival_hour  Arrival_min
# ...

# %%
df.drop('Arrival_Time',axis=1,inplace=True)
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55   2h 50m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year  \
# 0      1 stop                      No info    NaN     6      6  2019
# 1      1 stop                      No info    NaN    12      5  2019
# 2      1 stop  In-flight meal not included    NaN    21      5  2019
# 3      1 stop                      No info    NaN    21      5  2019
# 4    non-stop                      No info    NaN    24      6  2019
#
#    Arrival_hour  Arrival_min
# 0             4           25
# ...

# %%
df['dep_hour']=df['Dep_Time'].str.split(':').str[0].astype(int)
df['dep_min']=df['Dep_Time'].str.split(':').str[1].astype(int)
df.head()
# Out:
#              Airline    Source Destination            Route Dep_Time Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK    17:30  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR    06:20       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK    19:15  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK    08:00      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL    23:55   2h 50m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year  \
# 0      1 stop                      No info    NaN     6      6  2019
# 1      1 stop                      No info    NaN    12      5  2019
# 2      1 stop  In-flight meal not included    NaN    21      5  2019
# 3      1 stop                      No info    NaN    21      5  2019
# 4    non-stop                      No info    NaN    24      6  2019
#
#    Arrival_hour  Arrival_min  dep_hour  dep_min
# ...

# %%
df.drop('Dep_Time',axis=1,inplace=True)
df.head()
# Out:
#              Airline    Source Destination            Route Duration  \
# 0        Jet Airways     Delhi      Cochin  DEL → BOM → COK  10h 55m
# 1             IndiGo   Kolkata    Banglore  CCU → MAA → BLR       4h
# 2        Jet Airways     Delhi      Cochin  DEL → BOM → COK  23h 45m
# 3  Multiple carriers     Delhi      Cochin  DEL → BOM → COK      13h
# 4           Air Asia  Banglore       Delhi        BLR → DEL   2h 50m
#
#   Total_Stops              Additional_Info  Price  Date  Month  Year  \
# 0      1 stop                      No info    NaN     6      6  2019
# 1      1 stop                      No info    NaN    12      5  2019
# 2      1 stop  In-flight meal not included    NaN    21      5  2019
# 3      1 stop                      No info    NaN    21      5  2019
# 4    non-stop                      No info    NaN    24      6  2019
#
#    Arrival_hour  Arrival_min  dep_hour  dep_min
# 0             4           25        17       30
# ...

# %%
df.info().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13354 entries, 0 to 10682
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          13354 non-null  object
#  1   Source           13354 non-null  object
#  2   Destination      13354 non-null  object
#  3   Route            13353 non-null  object
#  4   Duration         13354 non-null  object
#  5   Total_Stops      13353 non-null  object
#  6   Additional_Info  13354 non-null  object
#  7   Price            10683 non-null  float64
#  8   Date             13354 non-null  int32
#  9   Month            13354 non-null  int32
#  10  Year             13354 non-null  int32
#  11  Arrival_hour     13354 non-null  int32
#  12  Arrival_min      13354 non-null  int32
#  13  dep_hour         13354 non-null  int32
#  14  dep_min          13354 non-null  int32
# dtypes: float64(1), int32(7), object(7)
# memory usage: 1.3+ MB
# ...

# %%
df['Total_Stops'].unique()
# Out:
# array(['1 stop', 'non-stop', '2 stops', '3 stops', '4 stops', nan],
#       dtype=object)

# %%
df[df['Total_Stops'].isnull()]
# Out:
#         Airline Source Destination Route Duration Total_Stops Additional_Info  \
# 9039  Air India  Delhi      Cochin   NaN  23h 40m         NaN         No info
#
#        Price  Date  Month  Year  Arrival_hour  Arrival_min  dep_hour  dep_min
# 9039  7480.0     6      5  2019             9           25         9       45

# %%
df['Total_Stops']=df['Total_Stops'].map({'1 stop':1, 'non-stop':0, '2 stops':2, '3 stops':3, '4 stops':4, 'nan':1})

# %%
df.drop('Route',axis=1,inplace=True)
df.head()
# Out:
#              Airline    Source Destination Duration  Total_Stops  \
# 0        Jet Airways     Delhi      Cochin  10h 55m          1.0
# 1             IndiGo   Kolkata    Banglore       4h          1.0
# 2        Jet Airways     Delhi      Cochin  23h 45m          1.0
# 3  Multiple carriers     Delhi      Cochin      13h          1.0
# 4           Air Asia  Banglore       Delhi   2h 50m          0.0
#
#                Additional_Info  Price  Date  Month  Year  Arrival_hour  \
# 0                      No info    NaN     6      6  2019             4
# 1                      No info    NaN    12      5  2019            10
# 2  In-flight meal not included    NaN    21      5  2019            19
# 3                      No info    NaN    21      5  2019            21
# 4                      No info    NaN    24      6  2019             2
#
#    Arrival_min  dep_hour  dep_min
# 0           25        17       30
# 1           20         6       20
# 2            0        19       15
# ...

# %%
df['Duration_t']=df['Duration'].str.split(' ').str[0].str.split('h').str[0]

# %%
df[df['Duration_t']=='5m']
# Out:
# Empty DataFrame
# Columns: [Airline, Source, Destination, Duration, Total_Stops, Additional_Info, Price, Date, Month, Year, Arrival_hour, Arrival_min, dep_hour, dep_min, Duration_t]
# Index: []

# %%
df.drop(2660,axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14200\666786465.py in <module>
# ----> 1 df.drop(2660,axis=0,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.drop(6474,axis=0,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14200\1389573315.py in <module>
# ----> 1 df.drop(6474,axis=0,inplace=True)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df['Duration_t']=df['Duration_t'].astype(int)

# %%
df['Duration_t']*60
# Out:
# 0         600
# 1         240
# 2        1380
# 3         780
# 4         120
#          ...
# 10678     120
# 10679     120
# 10680     180
# 10681     120
# 10682     480
# Name: Duration_t, Length: 13351, dtype: int32

# %%
df['Duration_m']=df['Duration'].str.split(' ').str[1].str.split('m').str[0]

# %%
df['Duration_m']
# Out:
# 0         55
# 1        NaN
# 2         45
# 3        NaN
# 4         50
#         ...
# 10678     30
# 10679     35
# 10680    NaN
# 10681     40
# 10682     20
# Name: Duration_m, Length: 13351, dtype: object

# %%
df['Duration_m']=df['Duration_m'].map({NaN:0})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14200\1166664839.py in <module>
# ----> 1 df['Duration_m']=df['Duration_m'].map({NaN:0})
#
# NameError: name 'NaN' is not defined

# %%
df['Duration_m']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10678   NaN
# 10679   NaN
# 10680   NaN
# 10681   NaN
# 10682   NaN
# Name: Duration_m, Length: 13351, dtype: float64
